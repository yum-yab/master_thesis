# %%
using Pkg

Pkg.activate(".")
# Out:
#   Activating project at `~/Documents/Uni/Master/MA/visual_analysis`

# %%
using BenchmarkTools

# %%
include("eof.jl")
# Out:
# eof (generic function with 1 method)

# %%
include("utils.jl")
# Out:
#     CondaPkg Found dependencies: /home/denis/Documents/Uni/Master/MA/visual_analysis/CondaPkg.toml
#     CondaPkg Found dependencies: /home/denis/.julia/packages/PythonCall/S5MOg/CondaPkg.toml
#     CondaPkg Dependencies already up to date
# get_mean_of_multiple_arrays (generic function with 1 method)

# %%
lon_dim = 100  # number of longitude points
lat_dim = 50   # number of latitude points
time_dim = 10  # number of time points

# Create a sample data array
data = rand(lon_dim, lat_dim, time_dim) .* 10000

# Generate latitude values (for example, from -90 to 90 degrees)
latitudes = LinRange(-90, 90, lat_dim)

# Calculate the weights as the cosine of the latitude values
weights = cos.(deg2rad.(latitudes))

nmodes = 5

my_impl = eof(data; nmodes = nmodes)

julia_pkg = get_eof_of_datachunk(data; nmodes = nmodes)

python_eofs = pyeof_of_datachunk(data, nmodes)
# Out:
# EOFResult([-0.02975749790745718 0.025766651213249236 … -0.018613003984060274 0.0006820080672172965; -0.000518205891377481 -0.010070042190505097 … 0.014283417504793729 0.004180595417967614; … ; 0.007836946581987187 -0.007168477251689969 … 0.00166384159633363 -0.02298320949479792; -0.013460625396911315 0.014432659797960988 … -0.01430866479356181 0.014877900868258596;;; 0.008422720896754905 0.012448467452380978 … -0.00316032444001148 0.009738263421264763; 0.006352334245111765 0.0197443922058457 … -0.010536684018112053 0.029037281040790733; … ; 0.03701746660402534 -0.01034406372660909 … -0.025226121468933032 -0.006860068993103382; 0.02491767792985136 -0.013958597570848103 … -0.0260079135773255 -0.016290824304030498;;; -0.014758156313129827 0.012751180114528023 … -0.0061476737098104545 0.023993406609096976; 0.01939475302684876 0.0009665519378135906 … -0.005708346956852046 0.017625033767341335; … ; -0.013971766311233865 -0.006916737027596677 … 0.006633314352169199 0.022370755282360696; 0.016680576651261717 -0.005403531883145778 … -0.017887156015735803 -0.002729014069623358;;; -0.003180843186569271 0.005062859833703844 … -0.027255799649260483 0.005709048276304185; -0.019860338974448888 -0.02525697591555271 … -0.03475267068474509 0.031208506533320843; … ; 0.0052776300975869075 -0.012422546662577959 … -0.013170310365041635 0.00887860127879414; -0.019002522858741693 -0.027428142863009344 … 0.009775608516110715 0.013552346424364373;;; -0.003501789403524479 -0.0010604184142887474 … 0.009206433803430693 0.0019464713204756143; 0.013703022150643283 0.003032830909529222 … 0.0013725186433979732 -0.010145424998808088; … ; -0.0045442494217186645 0.008540200203702204 … -0.00405826108299222 -0.01793898539496395; -0.014930185598920639 0.012315744435711876 … -0.0061583498666993725 -0.00013711313679928676], [-79819.65804009784 42798.93729869901 … 36133.50329187398 94664.12937788427; -21727.18898269879 -91555.98418715874 … -26511.92166579199 116094.53258922849; … ; -74689.1672914055 -58940.40897832211 … 6231.014761249866 -72525.48121299622; 53792.37296610282 53414.57105809664 … 17265.94010860221 -54733.24781929111], [11.909623025252817, 11.506878564851117, 11.31934753149192, 11.248778289580537, 11.127075394818563])

# %%
python_eofs.modes_variability
# Out:
# 5-element Vector{Float64}:
#  11.909623025252817
#  11.506878564851117
#  11.31934753149192
#  11.248778289580537
#  11.127075394818563

# %%
my_impl.spatial_modes == julia_pkg.spatial_modes
# Out:
# true

# %%
diffs = abs.(my_impl.spatial_modes .- python_eofs.spatial_modes)

maximum(diffs)
# Out:
# 4.7878367936959876e-15

# %%
function calculate_eofs_of_ensemble_multithreaded(
    ensemble::EnsembleSimulation,
    chunking,
    nmodes;
    center=true,
    align_eofs_with_mean=true,
    norm_withsqrt_timedim=false,
    geoweights=true,
    scale_mode=nothing,
    saving_filepath=nothing
)::Dict{String,Vector{EOFResult}}

    result = Dict{String,Vector{EOFResult}}()

    if geoweights
        weights = sqrt.(cos.(deg2rad.(ensemble.lats)))
    else
        weights = nothing
    end

    for (i, member) in enumerate(ensemble.members)
        # Predefined array for EOFResult

        # Function to handle EOF calculation


        # Decide whether to use threading based on CONDITION
        @time "Time it took for eof calculation for member $(member.id)" begin
            eofs = Vector{EOFResult}(undef, length(chunking))
            for idx in eachindex(chunking)
                eofs[idx] = eof(member.data[:, :, chunking[idx]]; nmodes=nmodes, center=center, align_eofs_with_mean=align_eofs_with_mean, norm_withsqrt_timedim=norm_withsqrt_timedim, weights=weights, scaling=scale_mode)
            end


            result[member.id] = eofs
        end
        flush(stdout)
    end

    if !isnothing(saving_filepath)
        try
            save(saving_filepath, result)
        catch e
            println("Couldn't save to filepath $saving_filepath: $e")
        end

    end

    return result

end
# Out:
# calculate_eofs_of_ensemble_multithreaded (generic function with 1 method)

# %%
function calculate_eofs_of_ensemble_single_thread(
    ensemble::EnsembleSimulation,
    chunking,
    nmodes;
    center=true,
    align_eofs_with_mean=true,
    norm_withsqrt_timedim=false,
    geoweights=true,
    scale_mode=nothing,
    saving_filepath=nothing
)::Dict{String,Vector{EOFResult}}

    result = Dict{String,Vector{EOFResult}}()

    if geoweights
        weights = sqrt.(cos.(deg2rad.(ensemble.lats)))
    else
        weights = nothing
    end

    for (i, member) in enumerate(ensemble.members)
        # Predefined array for EOFResult

        # Function to handle EOF calculation


        # Decide whether to use threading based on CONDITION
        @time "Time it took for eof calculation for member $(member.id)" begin
            eofs = Vector{EOFResult}(undef, length(chunking))
            Threads.@threads for idx in eachindex(chunking)
                eofs[idx] = eof(member.data[:, :, chunking[idx]]; nmodes=nmodes, center=center, align_eofs_with_mean=align_eofs_with_mean, norm_withsqrt_timedim=norm_withsqrt_timedim, weights=weights, scaling=scale_mode)
            end


            result[member.id] = eofs
        end
        flush(stdout)
    end

    if !isnothing(saving_filepath)
        try
            save(saving_filepath, result)
        catch e
            println("Couldn't save to filepath $saving_filepath: $e")
        end

    end

    return result

end
# Out:
# calculate_eofs_of_ensemble_single_thread (generic function with 1 method)

# %%
function filter_winter_season(time_element)
    winter_months = [12, 1, 2, 3]
    for wm in winter_months
        if month(time_element) == wm
            return true
        end
    end
    return false
end
# Out:
# filter_winter_season (generic function with 1 method)

# %%
ps_data_monthly_path = "/mnt/bigdrive/Datasets/master_thesis_data/ps_data_monthly"
ivt_data_monthly_path = "/mnt/bigdrive/Datasets/master_thesis_data/ivt_fields_monthly"
# Out:
# "/mnt/bigdrive/Datasets/master_thesis_data/ivt_fields_monthly"

# %%
(ivt_ssp585_monthly,) = build_ensemble_data(ivt_data_monthly_path, "ssp585"; file_range_selection=:, data_field_id="ivt", member_range=1:50, filterfun = filter_winter_season)
# Out:
# Handling scenario ssp585 ...
# 1-element Vector{EnsembleSimulation}:
#  EnsembleSimulation("ssp585", Union{Missing, AbstractFloat}[-90.0, -88.125, -86.25, -84.375, -82.5, -80.625, -78.75, -76.875, -75.0, -73.125  …  22.5, 24.375, 26.25, 28.125, 30.0, 31.875, 33.75, 35.625, 37.5, 39.375], Union{Missing, AbstractFloat}[21.450475037398185, 23.31573072614093, 25.180985581270594, 27.04623949994481, 28.91149236871774, 30.77674406172325, 32.64199443851768, 34.50724334150103, 36.37249059281224, 38.23773599056483  …  62.48557052203639, 64.35073040887207, 66.2158721139987, 68.08099098565125, 69.94608064698343, 71.81113211427447, 73.67613231320912, 75.54106145287895, 77.4058880820788, 79.27055903485967], Union{Missing, DateTime}[DateTime("2015-01-16T12:00:00"), DateTime("2015-02-14T21:00:00"), DateTime("2015-03-16T09:00:00"), DateTime("2015-12-16T09:00:00"), DateTime("2016-01-16T09:00:00"), DateTime("2016-02-15T09:00:00"), DateTime("2016-03-16T09:00:00"), DateTime("2016-12-16T09:00:00"), DateTime("2017-01-16T09:00:00"), DateTime("2017-02-14T21:00:00")  …  DateTime("2098-12-16T09:00:00"), DateTime("2099-01-16T09:00:00"), DateTime("2099-02-14T21:00:00"), DateTime("2099-03-16T09:00:00"), DateTime("2099-12-16T09:00:00"), DateTime("2100-01-16T09:00:00"), DateTime("2100-02-14T21:00:00"), DateTime("2100-03-16T09:00:00"), DateTime("2100-12-16T09:00:00"), DateTime("2101-01-01T00:00:00")], EnsembleMember[EnsembleMember("r1i1p1f1", Union{Missing, AbstractFloat}[173.25207497297566 154.70329292591035 … 15.862333342110459 15.127136195952614; 173.66888903924215 151.07999829119106 … 15.648277856639124 14.975253245391137; … ; 97.77969156480628 95.64578688713769 … 52.81567972171886 40.60192904077747; 84.72493402419241 79.88392607805092 … 52.81228647722293 40.95623059416815;;; 210.6738495721957 189.92835980981303 … 14.342212617069361 14.477730424871737; 221.94023535748778 203.40507496368102 … 14.267564462169478 14.129523395860202; … ; 86.88379357977145 76.70277667962135 … 51.565685552555 30.075683401115523; 102.34524980904577 75.77009624507248 … 50.204966457878825 29.112970935719936;;; 185.17536706308442 168.13220445337186 … 19.52255408647188 18.464549745806075; 195.0148383337875 176.55564179810838 … 19.21093370128155 18.29026194463849; … ; 110.35544927149988 112.64759111779311 … 43.79068824933889 38.95115406919523; 114.75629871277728 110.83584433990431 … 45.30092382850303 39.91364552903379;;; … ;;; 249.06432029916613 224.57717672008496 … 31.91340529663288 31.758626015553585; 262.36299521837253 218.59084306890955 … 32.12901014639323 31.619963811217566; … ; 95.80240217323272 84.40790813035835 … 91.24244295107367 84.94388388732126; 84.13075472664697 67.00725799058223 … 93.25561670342185 87.40386767438058;;; 288.1592386478208 252.0565890455286 … 20.56344017795827 20.36848157051988; 299.8906993588305 259.89440268745284 … 20.041252295748013 20.25592956171068; … ; 62.22652182154271 42.0659083073752 … 120.9141868204918 109.80552460883261; 41.94692622046048 26.871782672265905 … 118.58228853953696 109.63349169108429;;; 331.3877359456482 236.72734054027626 … 30.897574065747108 39.426546245040335; 321.58290954166694 232.63646865651765 … 26.826383944144787 36.64651885208341; … ; 72.26834863513643 52.24581127767189 … 228.9742103177028 191.34154435973878; 47.253701610974716 23.673628132069357 … 233.61834082711664 200.13318314793543]), EnsembleMember("r2i1p1f1", Union{Missing, AbstractFloat}[203.29766544989306 220.15453387683598 … 23.10302680084564 19.32234313337962; 214.281785632802 233.33678548682826 … 22.512971394253334 18.87617419983892; … ; 77.9357446167675 66.83223130633225 … 30.941976143145762 24.906152849438737; 61.44953683549155 54.91970724421587 … 30.507006638570882 24.231654319048747;;; 207.18124787922162 221.0179556827386 … 21.640720612553785 21.11881232327513; 235.72304181386082 236.94215439306862 … 20.471786620614317 20.403163620617644; … ; 47.035890742422325 50.264606187476694 … 40.621899735552056 36.84661868967912; 36.28327497846293 36.57671215884161 … 41.36082900567179 37.20702631143864;;; 190.7879398136825 196.554436144487 ...

# %%
chunks_50_seasons_scenario = get_sliding_time_scopes_by_threshold(ivt_ssp585_monthly.time, 50)
# Out:
# 37-element Vector{UnitRange{Int64}}:
#  1:201
#  4:205
#  8:209
#  12:213
#  16:217
#  20:221
#  24:225
#  28:229
#  32:233
#  36:237
#  ⋮
#  113:314
#  117:318
#  121:322
#  125:327
#  129:331
#  133:335
#  137:339
#  141:343
#  145:347

# %%
@benchmark calculate_eofs_of_ensemble_single_thread(
    $ivt_ssp585_monthly,
    $chunks_50_seasons_scenario,
    2;
    center=true,
    align_eofs_with_mean=true,
    norm_withsqrt_timedim=false,
    geoweights=true,
    scale_mode=:singularvals)
# Out:
# Time it took for eof calculation for member r1i1p1f1: 8.791490 seconds (35.22 M allocations: 4.189 GiB, 0.54% gc time, 222.32% compilation time)
# Time it took for eof calculation for member r2i1p1f1: 4.951817 seconds (33.56 M allocations: 4.080 GiB, 8.05% gc time)
# Time it took for eof calculation for member r3i1p1f1: 7.378953 seconds (33.56 M allocations: 4.080 GiB, 6.04% gc time)
# Time it took for eof calculation for member r4i1p1f1: 5.670071 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r5i1p1f1: 4.865262 seconds (33.56 M allocations: 4.080 GiB, 11.87% gc time)
# Time it took for eof calculation for member r6i1p1f1: 6.347048 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r7i1p1f1: 4.636049 seconds (33.56 M allocations: 4.080 GiB, 11.94% gc time)
# Time it took for eof calculation for member r8i1p1f1: 6.010152 seconds (33.56 M allocations: 4.080 GiB, 10.36% gc time)
# Time it took for eof calculation for member r9i1p1f1: 7.473027 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r10i1p1f1: 5.788571 seconds (33.56 M allocations: 4.080 GiB, 7.31% gc time)
# Time it took for eof calculation for member r11i1p1f1: 5.155927 seconds (33.56 M allocations: 4.080 GiB, 11.61% gc time)
# Time it took for eof calculation for member r12i1p1f1: 7.793363 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r13i1p1f1: 6.586056 seconds (33.56 M allocations: 4.081 GiB, 7.93% gc time)
# Time it took for eof calculation for member r14i1p1f1: 5.191958 seconds (33.56 M allocations: 4.080 GiB, 8.87% gc time)
# Time it took for eof calculation for member r15i1p1f1: 5.112549 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r16i1p1f1: 7.039431 seconds (33.56 M allocations: 4.080 GiB, 9.40% gc time)
# Time it took for eof calculation for member r17i1p1f1: 6.647950 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r18i1p1f1: 6.247588 seconds (33.56 M allocations: 4.080 GiB, 10.07% gc time)
# Time it took for eof calculation for member r19i1p1f1: 5.751602 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r20i1p1f1: 5.117896 seconds (33.56 M allocations: 4.080 GiB, 9.13% gc time)
# Time it took for eof calculation for member r21i1p1f1: 5.186725 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r22i1p1f1: 7.792983 seconds (33.56 M allocations: 4.080 GiB, 7.63% gc time)
# Time it took for eof calculation for member r23i1p1f1: 6.452963 seconds (33.56 M allocations: 4.080 GiB, 9.77% gc time)
# Time it took for eof calculation for member r24i1p1f1: 6.821396 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r25i1p1f1: 5.505162 seconds (33.56 M allocations: 4.080 GiB, 7.33% gc time)
# Time it took for eof calculation for member r26i1p1f1: 5.364910 seconds (33.56 M allocations: 4.080 GiB, 9.59% gc time)
# Time it took for eof calculation for member r27i1p1f1: 4.808454 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r28i1p1f1: 7.245636 seconds (33.56 M allocations: 4.080 GiB, 6.91% gc time)
# Time it took for eof calculation for member r29i1p1f1: 4.183202 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r30i1p1f1: 5.608006 seconds (33.56 M allocations: 4.080 GiB, 11.78% gc time)
# Time it took for eof calculation for member r31i1p1f1: 3.939553 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r32i1p1f1: 6.156960 seconds (33.56 M allocations: 4.080 GiB, 10.27% gc time)
# Time it took for eof calculation for member r33i1p1f1: 7.603020 seconds (33.56 M allocations: 4.080 GiB, 7.97% gc time)
# Time it took for eof calculation for member r34i1p1f1: 7.126002 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r35i1p1f1: 4.991486 seconds (33.56 M allocations: 4.080 GiB, 9.10% gc time)
# Time it took for eof calculation for member r36i1p1f1: 5.799625 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r37i1p1f1: 3.322549 seconds (33.56 M allocations: 4.080 GiB, 17.40% gc time)
# Time it took for eof calculation for member r38i1p1f1: 6.482100 seconds (33.56 M allocations: 4.081 GiB, 9.23% gc time)
# Time it took for eof calculation for member r39i1p1f1: 6.328917 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r40i1p1f1: 5.569943 seconds (33.56 M allocations: 4.080 GiB, 9.46% gc time)
# Time it took for eof calculation for member r41i1p1f1: 6.131389 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r42i1p1f1: 5.966474 seconds (33.56 M allocations: 4.081 GiB, 8.01% gc time)
# Time it took for eof calculation for member r43i1p1f1: 7.174097 seconds (33.56 M allocations: 4.080 GiB, 8.58% gc time)
# Time it took for eof calculation for member r44i1p1f1: 5.647757 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r45i1p1f1: 6.713938 seconds (33.56 M allocations: 4.080 GiB, 6.69% gc time)
# Time it took for eof calculation for member r46i1p1f1: 6.618692 seconds (33.56 M allocations: 4.081 GiB, 8.00% gc time)
# Time it took for eof calculation for member r47i1p1f1: 5.359064 seconds (33.56 M allocations: 4.081 GiB)
# Time it took for eof calculation for member r48i1p1f1: 5.838069 seconds (33.56 M allocations: 4.080 GiB, 9.84% gc time)
# Time it took for eof calculation for member r49i1p1f1: 6.642368 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r50i1p1f1: 7.295902 seconds (33.56 M allocations: 4.080 GiB, 6.86% gc time)
# Time it took for eof calculation for member r1i1p1f1: 6.495652 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r2i1p1f1: 6.003459 seconds (33.56 M allocations: 4.080 GiB, 6.57% gc time)
# Time it took for eof calculation for member r3i1p1f1: 6.589418 seconds (33.56 M allocations: 4.080 GiB, 6.45% gc time)
# Time it took for eof calculation for member r4i1p1f1: 5.316340 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r5i1p1f1: 5.227283 seconds (33.56 M allocations: 4.080 GiB, 10.12% gc time)
# Time it took for eof calculation for member r6i1p1f1: 5.685645 seconds (33.56 M allocations: 4.080 GiB, 9.50% gc time)
# Time it took for eof calculation for member r7i1p1f1: 5.772417 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r8i1p1f1: 5.503344 seconds (33.56 M allocations: 4.080 GiB, 11.49% gc time)
# Time it took for eof calculation for member r9i1p1f1: 6.106095 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r10i1p1f1: 3.585370 seconds (33.56 M allocations: 4.080 GiB, 13.72% gc time)
# Time it took for eof calculation for member r11i1p1f1: 4.277965 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r12i1p1f1: 6.229941 seconds (33.56 M allocations: 4.080 GiB, 8.13% gc time)
# Time it took for eof calculation for member r13i1p1f1: 7.792991 seconds (33.56 M allocations: 4.081 GiB, 6.91% gc time)
# Time it took for eof calculation for member r14i1p1f1: 6.078703 seconds (33.56 M allocations: 4.080 GiB, 7.07% gc time)
# Time it took for eof calculation for member r15i1p1f1: 6.918299 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r16i1p1f1: 4.982622 seconds (33.56 M allocations: 4.080 GiB, 12.76% gc time)
# Time it took for eof calculation for member r17i1p1f1: 4.682767 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r18i1p1f1: 6.430705 seconds (33.56 M allocations: 4.080 GiB, 6.16% gc time)
# Time it took for eof calculation for member r19i1p1f1: 5.295723 seconds (33.56 M allocations: 4.080 GiB, 8.55% gc time)
# Time it took for eof calculation for member r20i1p1f1: 5.169109 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r21i1p1f1: 7.158136 seconds (33.56 M allocations: 4.080 GiB, 7.62% gc time)
# Time it took for eof calculation for member r22i1p1f1: 4.835639 seconds (33.56 M allocations: 4.080 GiB, 11.15% gc time)
# Time it took for eof calculation for member r23i1p1f1: 4.435988 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r24i1p1f1: 5.454604 seconds (33.56 M allocations: 4.080 GiB, 9.87% gc time)
# Time it took for eof calculation for member r25i1p1f1: 4.641454 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r26i1p1f1: 7.031081 seconds (33.56 M allocations: 4.080 GiB, 6.68% gc time)
# Time it took for eof calculation for member r27i1p1f1: 6.437727 seconds (33.56 M allocations: 4.080 GiB, 7.98% gc time)
# Time it took for eof calculation for member r28i1p1f1: 4.754868 seconds (33.56 M allocations: 4.080 GiB, 9.21% gc time)
# Time it took for eof calculation for member r29i1p1f1: 5.961840 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r30i1p1f1: 6.383577 seconds (33.56 M allocations: 4.080 GiB, 9.25% gc time)
# Time it took for eof calculation for member r31i1p1f1: 5.812198 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r32i1p1f1: 7.303537 seconds (33.56 M allocations: 4.080 GiB, 8.05% gc time)
# Time it took for eof calculation for member r33i1p1f1: 4.238278 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r34i1p1f1: 5.433316 seconds (33.56 M allocations: 4.080 GiB, 9.56% gc time)
# Time it took for eof calculation for member r35i1p1f1: 4.952057 seconds (33.56 M allocations: 4.080 GiB, 11.83% gc time)
# Time it took for eof calculation for member r36i1p1f1: 5.285033 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r37i1p1f1: 6.379400 seconds (33.56 M allocations: 4.080 GiB, 10.60% gc time)
# Time it took for eof calculation for member r38i1p1f1: 5.891671 seconds (33.56 M allocations: 4.081 GiB)
# Time it took for eof calculation for member r39i1p1f1: 7.955807 seconds (33.56 M allocations: 4.080 GiB, 6.67% gc time)
# Time it took for eof calculation for member r40i1p1f1: 3.715101 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r41i1p1f1: 6.758345 seconds (33.56 M allocations: 4.080 GiB, 7.07% gc time)
# Time it took for eof calculation for member r42i1p1f1: 6.917523 seconds (33.56 M allocations: 4.081 GiB, 8.98% gc time)
# Time it took for eof calculation for member r43i1p1f1: 5.926025 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r44i1p1f1: 5.795504 seconds (33.56 M allocations: 4.080 GiB, 9.27% gc time)
# Time it took for eof calculation for member r45i1p1f1: 5.533075 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r46i1p1f1: 6.792764 seconds (33.56 M allocations: 4.081 GiB, 7.26% gc time)
# Time it took for eof calculation for member r47i1p1f1: 6.500804 seconds (33.56 M allocations: 4.081 GiB, 9.46% gc time)
# Time it took for eof calculation for member r48i1p1f1: 7.277487 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r49i1p1f1: 4.533621 seconds (33.56 M allocations: 4.080 GiB, 11.94% gc time)
# Time it took for eof calculation for member r50i1p1f1: 5.482801 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r1i1p1f1: 4.462457 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r2i1p1f1: 6.485119 seconds (33.56 M allocations: 4.080 GiB, 5.73% gc time)
# Time it took for eof calculation for member r3i1p1f1: 7.115007 seconds (33.56 M allocations: 4.080 GiB, 6.93% gc time)
# Time it took for eof calculation for member r4i1p1f1: 5.956948 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r5i1p1f1: 7.988139 seconds (33.56 M allocations: 4.080 GiB, 6.81% gc time)
# Time it took for eof calculation for member r6i1p1f1: 4.692925 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r7i1p1f1: 5.431463 seconds (33.56 M allocations: 4.080 GiB, 12.05% gc time)
# Time it took for eof calculation for member r8i1p1f1: 4.265103 seconds (33.56 M allocations: 4.080 GiB, 12.81% gc time)
# Time it took for eof calculation for member r9i1p1f1: 5.194219 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r10i1p1f1: 5.200686 seconds (33.56 M allocations: 4.080 GiB, 9.94% gc time)
# Time it took for eof calculation for member r11i1p1f1: 6.380566 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r12i1p1f1: 8.399150 seconds (33.56 M allocations: 4.080 GiB, 5.77% gc time)
# Time it took for eof calculation for member r13i1p1f1: 5.983269 seconds (33.56 M allocations: 4.081 GiB, 8.92% gc time)
# Time it took for eof calculation for member r14i1p1f1: 5.428792 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r15i1p1f1: 6.243617 seconds (33.56 M allocations: 4.080 GiB, 7.77% gc time)
# Time it took for eof calculation for member r16i1p1f1: 6.060233 seconds (33.56 M allocations: 4.080 GiB, 9.93% gc time)
# Time it took for eof calculation for member r17i1p1f1: 4.661382 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r18i1p1f1: 4.608910 seconds (33.56 M allocations: 4.080 GiB, 13.52% gc time)
# Time it took for eof calculation for member r19i1p1f1: 4.819060 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r20i1p1f1: 7.509682 seconds (33.56 M allocations: 4.080 GiB, 6.18% gc time)
# Time it took for eof calculation for member r21i1p1f1: 5.529214 seconds (33.56 M allocations: 4.080 GiB, 10.30% gc time)
# Time it took for eof calculation for member r22i1p1f1: 5.825554 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r23i1p1f1: 5.750338 seconds (33.56 M allocations: 4.080 GiB, 11.41% gc time)
# Time it took for eof calculation for member r24i1p1f1: 7.680792 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r25i1p1f1: 4.590290 seconds (33.56 M allocations: 4.080 GiB, 9.07% gc time)
# Time it took for eof calculation for member r26i1p1f1: 5.659481 seconds (33.56 M allocations: 4.080 GiB, 8.72% gc time)
# Time it took for eof calculation for member r27i1p1f1: 6.011788 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r28i1p1f1: 4.441031 seconds (33.56 M allocations: 4.080 GiB, 14.96% gc time)
# Time it took for eof calculation for member r29i1p1f1: 4.736535 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r30i1p1f1: 5.922432 seconds (33.56 M allocations: 4.080 GiB, 9.31% gc time)
# Time it took for eof calculation for member r31i1p1f1: 5.110508 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r32i1p1f1: 5.251651 seconds (33.56 M allocations: 4.080 GiB, 12.60% gc time)
# Time it took for eof calculation for member r33i1p1f1: 5.459054 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r34i1p1f1: 4.666824 seconds (33.56 M allocations: 4.080 GiB, 14.83% gc time)
# Time it took for eof calculation for member r35i1p1f1: 4.386953 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r36i1p1f1: 6.029821 seconds (33.56 M allocations: 4.080 GiB, 10.08% gc time)
# Time it took for eof calculation for member r37i1p1f1: 6.948793 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r38i1p1f1: 6.772339 seconds (33.56 M allocations: 4.081 GiB, 9.36% gc time)
# Time it took for eof calculation for member r39i1p1f1: 4.226144 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r40i1p1f1: 5.841811 seconds (33.56 M allocations: 4.080 GiB, 10.89% gc time)
# Time it took for eof calculation for member r41i1p1f1: 5.576824 seconds (33.56 M allocations: 4.080 GiB, 10.87% gc time)
# Time it took for eof calculation for member r42i1p1f1: 5.249963 seconds (33.56 M allocations: 4.081 GiB)
# Time it took for eof calculation for member r43i1p1f1: 5.578647 seconds (33.56 M allocations: 4.080 GiB, 9.01% gc time)
# Time it took for eof calculation for member r44i1p1f1: 6.191029 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r45i1p1f1: 6.056149 seconds (33.56 M allocations: 4.080 GiB, 8.90% gc time)
# Time it took for eof calculation for member r46i1p1f1: 4.311037 seconds (33.56 M allocations: 4.081 GiB)
# Time it took for eof calculation for member r47i1p1f1: 5.085004 seconds (33.56 M allocations: 4.081 GiB, 12.62% gc time)
# Time it took for eof calculation for member r48i1p1f1: 4.760042 seconds (33.56 M allocations: 4.080 GiB, 12.82% gc time)
# Time it took for eof calculation for member r49i1p1f1: 5.556954 seconds (33.56 M allocations: 4.080 GiB)
# Time it took for eof calculation for member r50i1p1f1: 7.976197 seconds (33.56 M allocations: 4.080 GiB, 6.99% gc time)
# BenchmarkTools.Trial: 1 sample with 1 evaluation.
#  Single result which took 284.075 s (5.76% GC) to evaluate,
#  with a memory estimate of 204.02 GiB, over 1677803794 allocations.

# %%
@benchmark calculate_eofs_of_ensemble_multithreaded(
    $ivt_ssp585_monthly,
    $chunks_50_seasons_scenario,
    2;
    center=true,
    align_eofs_with_mean=true,
    norm_withsqrt_timedim=false,
    geoweights=true,
    scale_mode=:singularvals
)
# Out:
# Time it took for eof calculation for member r1i1p1f1: 4.524882 seconds (33.56 M allocations: 4.080 GiB, 10.45% gc time)
# Time it took for eof calculation for member r2i1p1f1: 4.288469 seconds (33.56 M allocations: 4.080 GiB, 9.17% gc time)
# Time it took for eof calculation for member r3i1p1f1: 4.282391 seconds (33.56 M allocations: 4.080 GiB, 8.34% gc time)
# Time it took for eof calculation for member r4i1p1f1: 4.225646 seconds (33.56 M allocations: 4.080 GiB, 8.44% gc time)
# Time it took for eof calculation for member r5i1p1f1: 4.303004 seconds (33.56 M allocations: 4.080 GiB, 9.26% gc time)
# Time it took for eof calculation for member r6i1p1f1: 4.244764 seconds (33.56 M allocations: 4.080 GiB, 8.06% gc time)
# Time it took for eof calculation for member r7i1p1f1: 4.321233 seconds (33.56 M allocations: 4.080 GiB, 9.09% gc time)
# Time it took for eof calculation for member r8i1p1f1: 4.296857 seconds (33.56 M allocations: 4.080 GiB, 7.95% gc time)
# Time it took for eof calculation for member r9i1p1f1: 4.305175 seconds (33.56 M allocations: 4.080 GiB, 7.99% gc time)
# Time it took for eof calculation for member r10i1p1f1: 4.338223 seconds (33.56 M allocations: 4.080 GiB, 9.07% gc time)
# Time it took for eof calculation for member r11i1p1f1: 4.272856 seconds (33.56 M allocations: 4.080 GiB, 8.28% gc time)
# Time it took for eof calculation for member r12i1p1f1: 4.281478 seconds (33.56 M allocations: 4.080 GiB, 9.04% gc time)
# Time it took for eof calculation for member r13i1p1f1: 4.199274 seconds (33.56 M allocations: 4.081 GiB, 8.05% gc time)
# Time it took for eof calculation for member r14i1p1f1: 4.278388 seconds (33.56 M allocations: 4.080 GiB, 8.02% gc time)
# Time it took for eof calculation for member r15i1p1f1: 4.279903 seconds (33.56 M allocations: 4.080 GiB, 9.15% gc time)
# Time it took for eof calculation for member r16i1p1f1: 4.311525 seconds (33.56 M allocations: 4.080 GiB, 8.47% gc time)
# Time it took for eof calculation for member r17i1p1f1: 4.320081 seconds (33.56 M allocations: 4.080 GiB, 9.47% gc time)
# Time it took for eof calculation for member r18i1p1f1: 4.236959 seconds (33.56 M allocations: 4.080 GiB, 8.31% gc time)
# Time it took for eof calculation for member r19i1p1f1: 4.257263 seconds (33.56 M allocations: 4.080 GiB, 8.26% gc time)
# Time it took for eof calculation for member r20i1p1f1: 4.270560 seconds (33.56 M allocations: 4.080 GiB, 9.17% gc time)
# Time it took for eof calculation for member r21i1p1f1: 4.255281 seconds (33.56 M allocations: 4.080 GiB, 8.46% gc time)
# Time it took for eof calculation for member r22i1p1f1: 4.328073 seconds (33.56 M allocations: 4.080 GiB, 9.23% gc time)
# Time it took for eof calculation for member r23i1p1f1: 4.384744 seconds (33.56 M allocations: 4.080 GiB, 8.04% gc time)
# Time it took for eof calculation for member r24i1p1f1: 4.304588 seconds (33.56 M allocations: 4.080 GiB, 8.33% gc time)
# Time it took for eof calculation for member r25i1p1f1: 4.213803 seconds (33.56 M allocations: 4.080 GiB, 9.28% gc time)
# Time it took for eof calculation for member r26i1p1f1: 4.187805 seconds (33.56 M allocations: 4.080 GiB, 8.04% gc time)
# Time it took for eof calculation for member r27i1p1f1: 4.219544 seconds (33.56 M allocations: 4.080 GiB, 9.07% gc time)
# Time it took for eof calculation for member r28i1p1f1: 4.183459 seconds (33.56 M allocations: 4.080 GiB, 8.14% gc time)
# Time it took for eof calculation for member r29i1p1f1: 4.156437 seconds (33.56 M allocations: 4.080 GiB, 8.06% gc time)
# Time it took for eof calculation for member r30i1p1f1: 4.318123 seconds (33.56 M allocations: 4.080 GiB, 9.06% gc time)
# Time it took for eof calculation for member r31i1p1f1: 4.164970 seconds (33.56 M allocations: 4.080 GiB, 8.38% gc time)
# Time it took for eof calculation for member r32i1p1f1: 4.196332 seconds (33.56 M allocations: 4.080 GiB, 9.22% gc time)
# Time it took for eof calculation for member r33i1p1f1: 4.278261 seconds (33.56 M allocations: 4.080 GiB, 8.47% gc time)
# Time it took for eof calculation for member r34i1p1f1: 4.285898 seconds (33.56 M allocations: 4.080 GiB, 8.21% gc time)
# Time it took for eof calculation for member r35i1p1f1: 4.275255 seconds (33.56 M allocations: 4.080 GiB, 9.11% gc time)
# Time it took for eof calculation for member r36i1p1f1: 4.164960 seconds (33.56 M allocations: 4.080 GiB, 8.11% gc time)
# Time it took for eof calculation for member r37i1p1f1: 4.216135 seconds (33.56 M allocations: 4.080 GiB, 9.50% gc time)
# Time it took for eof calculation for member r38i1p1f1: 4.149063 seconds (33.56 M allocations: 4.081 GiB, 8.12% gc time)
# Time it took for eof calculation for member r39i1p1f1: 4.139943 seconds (33.56 M allocations: 4.080 GiB, 8.07% gc time)
# Time it took for eof calculation for member r40i1p1f1: 4.172314 seconds (33.56 M allocations: 4.080 GiB, 9.08% gc time)
# Time it took for eof calculation for member r41i1p1f1: 4.151903 seconds (33.56 M allocations: 4.080 GiB, 8.22% gc time)
# Time it took for eof calculation for member r42i1p1f1: 4.189151 seconds (33.56 M allocations: 4.081 GiB, 9.28% gc time)
# Time it took for eof calculation for member r43i1p1f1: 4.251598 seconds (33.56 M allocations: 4.080 GiB, 8.11% gc time)
# Time it took for eof calculation for member r44i1p1f1: 4.333459 seconds (33.56 M allocations: 4.080 GiB, 7.47% gc time)
# Time it took for eof calculation for member r45i1p1f1: 4.469071 seconds (33.56 M allocations: 4.080 GiB, 8.45% gc time)
# Time it took for eof calculation for member r46i1p1f1: 4.187756 seconds (33.56 M allocations: 4.081 GiB, 7.77% gc time)
# Time it took for eof calculation for member r47i1p1f1: 4.263927 seconds (33.56 M allocations: 4.081 GiB, 8.86% gc time)
# Time it took for eof calculation for member r48i1p1f1: 4.186710 seconds (33.56 M allocations: 4.080 GiB, 7.71% gc time)
# Time it took for eof calculation for member r49i1p1f1: 4.219616 seconds (33.56 M allocations: 4.080 GiB, 7.91% gc time)
# Time it took for eof calculation for member r50i1p1f1: 4.266412 seconds (33.56 M allocations: 4.080 GiB, 9.19% gc time)
# Time it took for eof calculation for member r1i1p1f1: 4.162376 seconds (33.56 M allocations: 4.080 GiB, 7.53% gc time)
# Time it took for eof calculation for member r2i1p1f1: 4.131319 seconds (33.56 M allocations: 4.080 GiB, 7.75% gc time)
# Time it took for eof calculation for member r3i1p1f1: 4.130099 seconds (33.56 M allocations: 4.080 GiB, 7.35% gc time)
# Time it took for eof calculation for member r4i1p1f1: 4.161779 seconds (33.56 M allocations: 4.080 GiB, 7.34% gc time)
# Time it took for eof calculation for member r5i1p1f1: 4.301481 seconds (33.56 M allocations: 4.080 GiB, 8.71% gc time)
# Time it took for eof calculation for member r6i1p1f1: 4.478287 seconds (33.56 M allocations: 4.080 GiB, 7.41% gc time)
# Time it took for eof calculation for member r7i1p1f1: 4.254129 seconds (33.56 M allocations: 4.080 GiB, 6.96% gc time)
# Time it took for eof calculation for member r8i1p1f1: 4.261156 seconds (33.56 M allocations: 4.080 GiB, 7.09% gc time)
# Time it took for eof calculation for member r9i1p1f1: 4.713699 seconds (33.56 M allocations: 4.080 GiB, 7.38% gc time)
# Time it took for eof calculation for member r10i1p1f1: 4.626095 seconds (33.56 M allocations: 4.080 GiB, 6.03% gc time)
# Time it took for eof calculation for member r11i1p1f1: 4.443713 seconds (33.56 M allocations: 4.080 GiB, 6.35% gc time)
# Time it took for eof calculation for member r12i1p1f1: 4.525474 seconds (33.56 M allocations: 4.080 GiB, 6.48% gc time)
# Time it took for eof calculation for member r13i1p1f1: 4.323367 seconds (33.56 M allocations: 4.081 GiB, 6.81% gc time)
# Time it took for eof calculation for member r14i1p1f1: 4.324574 seconds (33.56 M allocations: 4.080 GiB, 8.02% gc time)
# Time it took for eof calculation for member r15i1p1f1: 4.281681 seconds (33.56 M allocations: 4.080 GiB, 7.71% gc time)
# Time it took for eof calculation for member r16i1p1f1: 4.268013 seconds (33.56 M allocations: 4.080 GiB, 7.86% gc time)
# Time it took for eof calculation for member r17i1p1f1: 4.189509 seconds (33.56 M allocations: 4.080 GiB, 7.46% gc time)
# Time it took for eof calculation for member r18i1p1f1: 4.251803 seconds (33.56 M allocations: 4.080 GiB, 8.20% gc time)
# Time it took for eof calculation for member r19i1p1f1: 4.238652 seconds (33.56 M allocations: 4.080 GiB, 7.20% gc time)
# Time it took for eof calculation for member r20i1p1f1: 4.227119 seconds (33.56 M allocations: 4.080 GiB, 7.37% gc time)
# Time it took for eof calculation for member r21i1p1f1: 4.190968 seconds (33.56 M allocations: 4.080 GiB, 7.18% gc time)
# Time it took for eof calculation for member r22i1p1f1: 4.175261 seconds (33.56 M allocations: 4.080 GiB, 6.97% gc time)
# Time it took for eof calculation for member r23i1p1f1: 4.393868 seconds (33.56 M allocations: 4.080 GiB, 7.88% gc time)
# Time it took for eof calculation for member r24i1p1f1: 4.141350 seconds (33.56 M allocations: 4.080 GiB, 7.16% gc time)
# Time it took for eof calculation for member r25i1p1f1: 4.085203 seconds (33.56 M allocations: 4.080 GiB, 7.22% gc time)
# Time it took for eof calculation for member r26i1p1f1: 4.090618 seconds (33.56 M allocations: 4.080 GiB, 7.32% gc time)
# Time it took for eof calculation for member r27i1p1f1: 4.099619 seconds (33.56 M allocations: 4.080 GiB, 7.40% gc time)
# Time it took for eof calculation for member r28i1p1f1: 4.113985 seconds (33.56 M allocations: 4.080 GiB, 7.51% gc time)
# Time it took for eof calculation for member r29i1p1f1: 4.245696 seconds (33.56 M allocations: 4.080 GiB, 7.03% gc time)
# Time it took for eof calculation for member r30i1p1f1: 4.282049 seconds (33.56 M allocations: 4.080 GiB, 7.14% gc time)
# Time it took for eof calculation for member r31i1p1f1: 4.119809 seconds (33.56 M allocations: 4.080 GiB, 6.35% gc time)
# Time it took for eof calculation for member r32i1p1f1: 4.174750 seconds (33.56 M allocations: 4.080 GiB, 7.16% gc time)
# Time it took for eof calculation for member r33i1p1f1: 4.497427 seconds (33.56 M allocations: 4.080 GiB, 7.29% gc time)
# Time it took for eof calculation for member r34i1p1f1: 4.539129 seconds (33.56 M allocations: 4.080 GiB, 6.56% gc time)
# Time it took for eof calculation for member r35i1p1f1: 4.330175 seconds (33.56 M allocations: 4.080 GiB, 7.14% gc time)
# Time it took for eof calculation for member r36i1p1f1: 4.246191 seconds (33.56 M allocations: 4.080 GiB, 6.83% gc time)
# Time it took for eof calculation for member r37i1p1f1: 4.399544 seconds (33.56 M allocations: 4.080 GiB, 7.41% gc time)
# Time it took for eof calculation for member r38i1p1f1: 4.433713 seconds (33.56 M allocations: 4.081 GiB, 7.85% gc time)
# Time it took for eof calculation for member r39i1p1f1: 4.389159 seconds (33.56 M allocations: 4.080 GiB, 8.28% gc time)
# Time it took for eof calculation for member r40i1p1f1: 4.460566 seconds (33.56 M allocations: 4.080 GiB, 7.54% gc time)
# Time it took for eof calculation for member r41i1p1f1: 4.375032 seconds (33.56 M allocations: 4.080 GiB, 7.37% gc time)
# Time it took for eof calculation for member r42i1p1f1: 4.162172 seconds (33.56 M allocations: 4.081 GiB, 8.06% gc time)
# Time it took for eof calculation for member r43i1p1f1: 4.183105 seconds (33.56 M allocations: 4.080 GiB, 7.15% gc time)
# Time it took for eof calculation for member r44i1p1f1: 4.324909 seconds (33.56 M allocations: 4.080 GiB, 8.12% gc time)
# Time it took for eof calculation for member r45i1p1f1: 4.079556 seconds (33.56 M allocations: 4.080 GiB, 7.29% gc time)
# Time it took for eof calculation for member r46i1p1f1: 4.351532 seconds (33.56 M allocations: 4.081 GiB, 7.29% gc time)
# Time it took for eof calculation for member r47i1p1f1: 4.333891 seconds (33.56 M allocations: 4.081 GiB, 8.34% gc time)
# Time it took for eof calculation for member r48i1p1f1: 4.394106 seconds (33.56 M allocations: 4.080 GiB, 7.04% gc time)
# Time it took for eof calculation for member r49i1p1f1: 4.389122 seconds (33.56 M allocations: 4.080 GiB, 7.93% gc time)
# Time it took for eof calculation for member r50i1p1f1: 4.374520 seconds (33.56 M allocations: 4.080 GiB, 6.88% gc time)
# Time it took for eof calculation for member r1i1p1f1: 4.316427 seconds (33.56 M allocations: 4.080 GiB, 7.01% gc time)
# Time it took for eof calculation for member r2i1p1f1: 4.560676 seconds (33.56 M allocations: 4.080 GiB, 7.11% gc time)
# Time it took for eof calculation for member r3i1p1f1: 4.491413 seconds (33.56 M allocations: 4.080 GiB, 6.94% gc time)
# Time it took for eof calculation for member r4i1p1f1: 4.867731 seconds (33.56 M allocations: 4.080 GiB, 6.98% gc time)
# Time it took for eof calculation for member r5i1p1f1: 4.576837 seconds (33.56 M allocations: 4.080 GiB, 7.57% gc time)
# Time it took for eof calculation for member r6i1p1f1: 4.365799 seconds (33.56 M allocations: 4.080 GiB, 6.89% gc time)
# Time it took for eof calculation for member r7i1p1f1: 4.207948 seconds (33.56 M allocations: 4.080 GiB, 6.98% gc time)
# Time it took for eof calculation for member r8i1p1f1: 4.282177 seconds (33.56 M allocations: 4.080 GiB, 7.04% gc time)
# Time it took for eof calculation for member r9i1p1f1: 4.333449 seconds (33.56 M allocations: 4.080 GiB, 7.78% gc time)
# Time it took for eof calculation for member r10i1p1f1: 4.281007 seconds (33.56 M allocations: 4.080 GiB, 7.02% gc time)
# Time it took for eof calculation for member r11i1p1f1: 4.253995 seconds (33.56 M allocations: 4.080 GiB, 7.60% gc time)
# Time it took for eof calculation for member r12i1p1f1: 4.332793 seconds (33.56 M allocations: 4.080 GiB, 7.30% gc time)
# Time it took for eof calculation for member r13i1p1f1: 4.339154 seconds (33.56 M allocations: 4.081 GiB, 7.25% gc time)
# Time it took for eof calculation for member r14i1p1f1: 4.408153 seconds (33.56 M allocations: 4.080 GiB, 8.06% gc time)
# Time it took for eof calculation for member r15i1p1f1: 4.372747 seconds (33.56 M allocations: 4.080 GiB, 7.28% gc time)
# Time it took for eof calculation for member r16i1p1f1: 4.399671 seconds (33.56 M allocations: 4.080 GiB, 6.94% gc time)
# Time it took for eof calculation for member r17i1p1f1: 4.273280 seconds (33.56 M allocations: 4.080 GiB, 7.30% gc time)
# Time it took for eof calculation for member r18i1p1f1: 4.244292 seconds (33.56 M allocations: 4.080 GiB, 7.93% gc time)
# Time it took for eof calculation for member r19i1p1f1: 4.176693 seconds (33.56 M allocations: 4.080 GiB, 7.09% gc time)
# Time it took for eof calculation for member r20i1p1f1: 4.284649 seconds (33.56 M allocations: 4.080 GiB, 6.87% gc time)
# Time it took for eof calculation for member r21i1p1f1: 4.282927 seconds (33.56 M allocations: 4.080 GiB, 7.34% gc time)
# Time it took for eof calculation for member r22i1p1f1: 4.414207 seconds (33.56 M allocations: 4.080 GiB, 7.42% gc time)
# Time it took for eof calculation for member r23i1p1f1: 4.339060 seconds (33.56 M allocations: 4.080 GiB, 8.07% gc time)
# Time it took for eof calculation for member r24i1p1f1: 4.327931 seconds (33.56 M allocations: 4.080 GiB, 7.35% gc time)
# Time it took for eof calculation for member r25i1p1f1: 4.299069 seconds (33.56 M allocations: 4.080 GiB, 7.13% gc time)
# Time it took for eof calculation for member r26i1p1f1: 4.309121 seconds (33.56 M allocations: 4.080 GiB, 7.58% gc time)
# Time it took for eof calculation for member r27i1p1f1: 4.196958 seconds (33.56 M allocations: 4.080 GiB, 7.24% gc time)
# Time it took for eof calculation for member r28i1p1f1: 4.374989 seconds (33.56 M allocations: 4.080 GiB, 7.22% gc time)
# Time it took for eof calculation for member r29i1p1f1: 4.205722 seconds (33.56 M allocations: 4.080 GiB, 7.27% gc time)
# Time it took for eof calculation for member r30i1p1f1: 4.505765 seconds (33.56 M allocations: 4.080 GiB, 7.09% gc time)
# Time it took for eof calculation for member r31i1p1f1: 4.505856 seconds (33.56 M allocations: 4.080 GiB, 6.54% gc time)
# Time it took for eof calculation for member r32i1p1f1: 4.304780 seconds (33.56 M allocations: 4.080 GiB, 7.56% gc time)
# Time it took for eof calculation for member r33i1p1f1: 4.191033 seconds (33.56 M allocations: 4.080 GiB, 7.49% gc time)
# Time it took for eof calculation for member r34i1p1f1: 4.162583 seconds (33.56 M allocations: 4.080 GiB, 7.24% gc time)
# Time it took for eof calculation for member r35i1p1f1: 4.392060 seconds (33.56 M allocations: 4.080 GiB, 7.13% gc time)
# Time it took for eof calculation for member r36i1p1f1: 4.328999 seconds (33.56 M allocations: 4.080 GiB, 7.52% gc time)
# Time it took for eof calculation for member r37i1p1f1: 4.300796 seconds (33.56 M allocations: 4.080 GiB, 7.46% gc time)
# Time it took for eof calculation for member r38i1p1f1: 4.332807 seconds (33.56 M allocations: 4.081 GiB, 7.60% gc time)
# Time it took for eof calculation for member r39i1p1f1: 4.340532 seconds (33.56 M allocations: 4.080 GiB, 7.57% gc time)
# Time it took for eof calculation for member r40i1p1f1: 4.481193 seconds (33.56 M allocations: 4.080 GiB, 7.49% gc time)
# Time it took for eof calculation for member r41i1p1f1: 4.298861 seconds (33.56 M allocations: 4.080 GiB, 7.40% gc time)
# Time it took for eof calculation for member r42i1p1f1: 4.339144 seconds (33.56 M allocations: 4.081 GiB, 8.43% gc time)
# Time it took for eof calculation for member r43i1p1f1: 4.384477 seconds (33.56 M allocations: 4.080 GiB, 7.34% gc time)
# Time it took for eof calculation for member r44i1p1f1: 4.307459 seconds (33.56 M allocations: 4.080 GiB, 8.40% gc time)
# Time it took for eof calculation for member r45i1p1f1: 4.284868 seconds (33.56 M allocations: 4.080 GiB, 7.98% gc time)
# Time it took for eof calculation for member r46i1p1f1: 4.346989 seconds (33.56 M allocations: 4.081 GiB, 7.35% gc time)
# Time it took for eof calculation for member r47i1p1f1: 4.294977 seconds (33.56 M allocations: 4.081 GiB, 8.28% gc time)
# Time it took for eof calculation for member r48i1p1f1: 4.366721 seconds (33.56 M allocations: 4.080 GiB, 7.53% gc time)
# Time it took for eof calculation for member r49i1p1f1: 4.243343 seconds (33.56 M allocations: 4.080 GiB, 8.10% gc time)
# Time it took for eof calculation for member r50i1p1f1: 4.195647 seconds (33.56 M allocations: 4.080 GiB, 7.44% gc time)
# BenchmarkTools.Trial: 1 sample with 1 evaluation.
#  Single result which took 217.035 s (7.41% GC) to evaluate,
#  with a memory estimate of 204.02 GiB, over 1677799181 allocations.
